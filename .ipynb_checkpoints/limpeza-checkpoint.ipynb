# %% [raw]
# Notebook para limpeza dos dados

# %%
import pandas as pd

# %%
df = pd.read_csv("ocorrencia_2010_2020.csv", sep=";", parse_dates = ["ocorrencia_dia"], dayfirst = True)
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %% [raw]
# Localização de um dado desejado por linha e coluna:

# %%
df.loc[1,'ocorrencia_cidade']
# Out:
# 'BELÉM'

# %%
df.loc[0:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0

# %% [raw]
# Mostra os dados da linha 10 e da linha 40:
# df.loc[[10,40]]

# %% [raw]
# Mostra todos os dados da coluna 'ocorrencia_cidade':
# df.loc[:,'ocorrencia_cidade']

# %% [raw]
# Verifica se a coluna tem valores únicos:

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %% [raw]
# Definindo a coluna como label do dataframe nesse momento(não é alteração no dataframe inteiro):
# df.set_index('codigo_ocorrencia')

# %% [raw]
# Alterando o label no dataframe:

# %%
df.set_index('codigo_ocorrencia',inplace=True)

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_uf  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE            RJ
# 40349                           40349                INCIDENTE            PA
# 40351                           40351                INCIDENTE            RJ
# 39527                           39527                 ACIDENTE            MT
# 40324                           40324                INCIDENTE            RS
#
#                   ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# codigo_ocorrencia
# 40211                             ****     2010-01-03        12:00:00
# 40349                             SBBE     2010-01-03        11:05:00
# 40351                             SBRJ     2010-01-03        03:00:00
# 39527                             ****     2010-01-04        17:30:00
# 40324                             SBPK     2010-01-05        19:25:00
#
#                    total_recomendacoes
# ...

# %% [raw]
# Buscando os dados pelo novo label:

# %%
df.loc[40211]
# Out:
# codigo_ocorrencia2                        40211
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_uf                                RJ
# ocorrencia_aerodromo                       ****
# ocorrencia_dia              2010-01-03 00:00:00
# ocorrencia_hora                        12:00:00
# total_recomendacoes                           0
# Name: 40211, dtype: object

# %% [raw]
# Resetando o label do dataframe para o original:

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_uf  \
# 0               40211                INCIDENTE            RJ
# 1               40349                INCIDENTE            PA
# 2               40351                INCIDENTE            RJ
# 3               39527                 ACIDENTE            MT
# 4               40324                INCIDENTE            RS
#
#   ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0                 ****     2010-01-03        12:00:00                    0
# 1                 SBBE     2010-01-03        11:05:00                    0
# 2                 SBRJ     2010-01-03        03:00:00                    0
# 3                 ****     2010-01-04        17:30:00                    0
# 4                 SBPK     2010-01-05        19:25:00                    0

# %% [raw]
# Altera valor da linha 0 e coluna 'ocorrencia_aerodromo' para vazio:

# %%
df.loc[0,'ocorrencia_aerodromo'] = ''

# %%
df.head(1)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_uf  \
# 0               40211                INCIDENTE            RJ
#
#   ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0                          2010-01-03        12:00:00                    0

# %% [raw]
# Altera todos os valores da linha 1 para 20:
# df.loc[1] = 20
#
# Altera todos os valores da coluna 'total_recomendacoes' para 10:
# df.loc[:,'total_recomendacoes'] = 10

# %% [raw]
# Fazendo o backup de uma coluna antes de alterá-la, ou seja, criando uma nova:
# df['ocorrencia_uf_bkp'] = df.ocorrencia_uf

# %% [raw]
# Alterando para 'GRAVE' o valor da coluna 'ocorrencia_classificacao' onde a 'ocorrencia_uf' seja 'SP' (usando filtro):
# df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'

# %% [raw]
# Filtrando os dados onde 'ocorrencia_uf' seja igual a 'SP':
# df.loc[df.ocorrencia_uf == 'SP']

# %% [raw]
# Dados para limpeza
#
# ocorrencia_uf:
# **
#
# ocorrencia_aerodromo:
# ****
# *****
# ###!
# ####
#
# ocorrencia_hora:
# NULL

# %% [raw]
# Alterando o valor da célula onde tem '****' da coluna ocorrencia_aerodromo usando a forma de atribuir valores não informados pelo próprio pandas. Dessa forma, teria que alterar para cada símbolo, o que é trabalhoso.

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.replace(['**', '****', '*****', '###!', '####', 'NULL', ''], pd.NA, inplace=True)

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_uf  \
# 0                  40211                INCIDENTE            RJ
# 1                  40349                INCIDENTE            PA
# 2                  40351                INCIDENTE            RJ
# 3                  39527                 ACIDENTE            MT
# 4                  40324                INCIDENTE            RS
# ...                  ...                      ...           ...
# 5747               79804                INCIDENTE            SP
# 5748               79757          INCIDENTE GRAVE            TO
# 5749               79802                INCIDENTE            RJ
# 5750               79756          INCIDENTE GRAVE            MS
# 5751               79844                INCIDENTE            RJ
#
#      ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0                    <NA>     2010-01-03        12:00:00                    0
# ...

# %% [raw]
# Soma os valores que sejam do tipo NA, não informado:

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2349
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %% [raw]
# Cria coluna de backup:

# %%
df['total_recomendacoes_bkp'] = df.total_recomendacoes

# %%
df
# Out:
#      codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_uf  \
# 0                 40211                INCIDENTE            RJ
# 1                 40349                INCIDENTE            PA
# 2                 40351                INCIDENTE            RJ
# 3                 39527                 ACIDENTE            MT
# 4                 40324                INCIDENTE            RS
# ...                 ...                      ...           ...
# 5747              79804                INCIDENTE            SP
# 5748              79757          INCIDENTE GRAVE            TO
# 5749              79802                INCIDENTE            RJ
# 5750              79756          INCIDENTE GRAVE            MS
# 5751              79844                INCIDENTE            RJ
#
#      ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes  \
# 0                    <NA>     2010-01-03        12:00:00                    0
# ...

# %% [raw]
# Deletando a coluna criada anteriormente do dataframe:

# %%
df.drop(['total_recomendacoes_bkp'],axis=1, inplace=True)

# %% [raw]
# Deletando todas as linhas que tenham valor NA do dataframe nesse instante (não substitui no dataframe):

# %%
df.dropna()
# Out:
#      codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_uf  \
# 1                 40349                INCIDENTE            PA
# 2                 40351                INCIDENTE            RJ
# 4                 40324                INCIDENTE            RS
# 6                 40215                INCIDENTE            AM
# 8                 39156          INCIDENTE GRAVE            PR
# ...                 ...                      ...           ...
# 5743              79824                 ACIDENTE            MG
# 5746              79769          INCIDENTE GRAVE            AC
# 5747              79804                INCIDENTE            SP
# 5749              79802                INCIDENTE            RJ
# 5751              79844                INCIDENTE            RJ
#
#      ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 1                    SBBE     2010-01-03        11:05:00                    0
# ...

# %%
df
# Out:
#      codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_uf  \
# 0                 40211                INCIDENTE            RJ
# 1                 40349                INCIDENTE            PA
# 2                 40351                INCIDENTE            RJ
# 3                 39527                 ACIDENTE            MT
# 4                 40324                INCIDENTE            RS
# ...                 ...                      ...           ...
# 5747              79804                INCIDENTE            SP
# 5748              79757          INCIDENTE GRAVE            TO
# 5749              79802                INCIDENTE            RJ
# 5750              79756          INCIDENTE GRAVE            MS
# 5751              79844                INCIDENTE            RJ
#
#      ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0                    <NA>     2010-01-03        12:00:00                    0
# ...
